# %%
import pandas as pd

df = pd.read_csv("C:/Users/Ashkan/Desktop/fiding similar rows/student-mat.csv", sep=';')
features = ["sex", "Pstatus", "Medu", "Fedu", "Mjob", "Fjob", "studytime", "internet", "G1", "G2", "G3"]
df.loc[102, features]
